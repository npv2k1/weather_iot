# %%
import numpy as np
import pandas as pd
import math
import sys

from sklearn.datasets import make_classification
from sklearn.datasets import make_regression

from sklearn.metrics import accuracy_score
from sklearn.metrics import r2_score

# %%
class DecisionNode:
    """
    Class for a parent/leaf node in the decision tree.
    A Node with node information about it's left and right nodes if any. it has the impurity info also.
    """
    def __init__(self, impurity=None, question=None, feature_index=None, threshold=None,
                 true_subtree=None, false_subtree=None):
        """
        :param
        """
        self.impurity = impurity
        # Which question to ask , to split the dataset.
        self.question = question 
        # Index of the feature which make the best fit for this node.
        self.feature_index = feature_index
        # The threshold value for that feature to make the split.
        self.threshold = threshold
        # DecisionNode Object of the left subtree.
        self.true_left_subtree = true_subtree
        # DecisionNode Object of the right subtree.
        self.false_right_subtree = false_subtree

class LeafNode:
    """ Leaf Node of the decision tree."""
    def __init__(self, value):
        self.prediction_value = value

# %%
class DecisionTree:
    """Common class for making decision tree for classification and regression tasks."""
    def __init__(self, min_sample_split=3, min_impurity=1e-7, max_depth=float('inf'),
                 impurity_function=None, leaf_node_calculation=None):
        """
        """
        self.root = None

        self.min_sample_split = min_sample_split
        self.min_impurity = min_impurity
        self.max_depth = max_depth
        self.impurity_function = impurity_function
        self.leaf_node_calculation = leaf_node_calculation

    def _partition_dataset(self, Xy, feature_index, threshold):
        """Split the dataset based on the given feature and threshold.
        
        """
        split_func = None
        if isinstance(threshold, int) or isinstance(threshold, float):
            split_func = lambda sample: sample[feature_index] >= threshold
        else:
            split_func = lambda sample: sample[feature_index] == threshold

        X_1 = np.array([sample for sample in Xy if split_func(sample)])
        X_2 = np.array([sample for sample in Xy if not split_func(sample)])

        return X_1, X_2

    def _find_best_split(self, Xy):
        """ Find the best question/best feature threshold which splits the data well.
        
        """
        best_question = tuple() # this will containe the feature and its value which make the best split(higest gain).
        best_datasplit = {} # best data split.
        largest_impurity = 0
        n_features = (Xy.shape[1] - 1)
        # iterate over all the features.
        for feature_index in range(n_features):
            # find the unique values in that feature.
            unique_value = set(s for s in Xy[:,feature_index])
            # iterate over all the unique values to find the impurity.
            for threshold in unique_value:
                # split the dataset based on the feature value.
                true_xy, false_xy = self._partition_dataset(Xy, feature_index, threshold)
                # skip the node which has any on type 0. because this means it is already pure.
                if len(true_xy) > 0 and len(false_xy) > 0:
                    

                    # find the y values.
                    y = Xy[:, -1]
                    true_y = true_xy[:, -1]
                    false_y = false_xy[:, -1]

                    # calculate the impurity function.
                    impurity = self.impurity_function(y, true_y, false_y)

                    # if the calculated impurity is larger than save this value for comaparition.
                    if impurity > largest_impurity:
                        largest_impurity = impurity
                        best_question = (feature_index, threshold)
                        best_datasplit = {
                                    "leftX": true_xy[:, :n_features],   # X of left subtree
                                    "lefty": true_xy[:, n_features:],   # y of left subtree
                                    "rightX": false_xy[:, :n_features],  # X of right subtree
                                    "righty": false_xy[:, n_features:]   # y of right subtree
                        }
                    
        return largest_impurity, best_question, best_datasplit

    def _build_tree(self, X, y, current_depth=0):
        """
        This is a recursive method to build the decision tree.
        """
        n_samples , n_features = X.shape
        # Add y as last column of X
        Xy = np.concatenate((X, y), axis=1)
        # find the Information gain on each feature each values and return the question which splits the data very well
        # based on the impurity function. (classfication - Information gain, regression - variance reduction).
        if (n_samples >= self.min_sample_split) and (current_depth <= self.max_depth):
            # find the best split/ which question split the data well.
            impurity, quesion, best_datasplit = self._find_best_split(Xy)
            if impurity > self.min_impurity:
            # Build subtrees for the right and left branch.
                true_branch = self._build_tree(best_datasplit["leftX"], best_datasplit["lefty"], current_depth + 1)
                false_branch = self._build_tree(best_datasplit["rightX"], best_datasplit["righty"], current_depth + 1)
                return DecisionNode( impurity=impurity, question=quesion, feature_index=quesion[0], threshold=quesion[1],
                                    true_subtree=true_branch, false_subtree=false_branch)

        leaf_value = self._leaf_value_calculation(y)
        return LeafNode(value=leaf_value)


    def train(self, X, y):
        """
        Build the decision tree.

        :param X: Train features/dependant values.
        :param y: train target/independant value.
        """
        self.root = self._build_tree(X, y, current_depth=0)

    def predict_sample(self, x, tree=None):
        """move form the top to bottom of the tree make a prediction of the sample by the
            value in the leaf node """
        if tree is None:
            tree = self.root
        # if it a leaf node the return the prediction.
        if isinstance(tree , LeafNode):

            return tree.prediction_value
        feature_value = x[tree.feature_index]

        branch = tree.false_right_subtree

        if isinstance(feature_value, int) or isinstance(feature_value, float):
            
            if feature_value >= tree.threshold:

                branch = tree.true_left_subtree
        elif feature_value == tree.threshold:
            branch = tree.true_left_subtree

        return self.predict_sample(x, branch)

    def predict(self, test_X):
        """ predict the unknow feature."""
        x = np.array(test_X)
        y_pred = [self.predict_sample(sample) for sample in x]
        # y_pred = np.array(y_pred)
        # y_pred = np.expand_dims(y_pred, axis = 1)
        return y_pred
    
    def draw_tree(self, tree = None, indentation = " "):
        """print the whole decitions of the tree from top to bottom."""
        if tree is None:
            tree = self.root

        def print_question(question, indention):
            """
            :param question: tuple of feature_index and threshold.
            """
            feature_index = question[0]
            threshold = question[1]

            condition = "=="
            if isinstance(threshold, int) or isinstance(threshold, float):
                condition = ">="
            print(indention,"Is {col}{condition}{value}?".format(col=feature_index, condition=condition, value=threshold))

        if isinstance(tree , LeafNode):
            print(indentation,"The predicted value -->", tree.prediction_value)
            return
        
        else:
            # print the question.
            print_question(tree.question,indentation)
            if tree.true_left_subtree is not None:
                # travers to the true left branch.
                print (indentation + '----- True branch :)')
                self.draw_tree(tree.true_left_subtree, indentation + "  ")
            if tree.false_right_subtree is not None:
                # travers to the false right-side branch.
                print (indentation + '----- False branch :)')
                self.draw_tree(tree.false_right_subtree, indentation + "  ")

# %%
class DecisionTreeClassifier(DecisionTree):
    """ Decision Tree for the classification problem."""
    def __init__(self, min_sample_split=3, min_impurity=1e-7, max_depth=float('inf'),
                 ):
        """
        :param min_sample_split: min value a leaf node must have.
        :param min_impurity: minimum impurity.
        :param max_depth: maximum depth of the tree.
        """
        self._impurity_function = self._claculate_information_gain
        self._leaf_value_calculation = self._calculate_majarity_class
        super(DecisionTreeClassifier, self).__init__(min_sample_split=min_sample_split, min_impurity=min_impurity, max_depth=max_depth,
                         impurity_function=self._impurity_function, leaf_node_calculation=self._leaf_value_calculation)
    
    def _entropy(self, y):
        """ Find the entropy for the given data"""
        entropy = 0
        unique_value = np.unique(y)
        for val in unique_value:
            # probability of that class.
            p = len(y[y==val]) / len(y)
            entropy += -p * (math.log(p) / math.log(2))
        return entropy


    def _claculate_information_gain(self, y, y1, y2):
        """
        Calculate the information gain.

        :param y: target value.
        :param y1: target value for dataset in the true split/right branch.
        :param y2: target value for dataset in the false split/left branch.
        """
        # propobility of true values.
        p = len(y1) / len(y)
        entropy = self._entropy(y)
        info_gain = entropy - p * self._entropy(y1) - (1 - p) * self._entropy(y2)
        return info_gain       

    def _calculate_majarity_class(self, y):
        """
        calculate the prediction value for that leaf node.
        
        :param y: leaf node target array.
        """
        most_frequent_label = None
        max_count = 0
        unique_labels = np.unique(y)
        # iterate over all the unique values and find their frequentcy count.
        for label in unique_labels:
            count = len( y[y == label])
            if count > max_count:
                most_frequent_label = label
                max_count = count
        return most_frequent_label

    def train(self, X, y):
        """
        Build the tree.

        :param X: Feature array/depentant values.
        :parma y: target array/indepentant values.
        """
        # train the model.
        super(DecisionTreeClassifier, self).train(X, y)
    
    def predict(self, test_X):
        """ predict the unknow feature."""
        y_pred = super(DecisionTreeClassifier, self).predict(test_X)
        y_pred = np.array(y_pred)
        y_pred = np.expand_dims(y_pred, axis = 1)
        return y_pred

# %% [markdown]
# # Data Creation.

# %%
# X = np.array([["Green", 3], ["yello", 3], ["orange_color", 2], ["orange_color", 2], ["red", 1]])
# y = np.array(["apply", "apply", "orange", "orange", "cherry"])
# X = pd.DataFrame(X)
# y = pd.DataFrame(y)
# y.head

# Define the traning data.
X, y = make_classification(n_samples=1000, n_classes=2, n_features=5)

# Chnage the shape of the target to 1 dimentional array.
y = y[:, np.newaxis]

print("="*100)
print("Number of training data samples-----> {}".format(X.shape[0]))
print("Number of training features --------> {}".format(X.shape[1]))
print("Shape of the target value ----------> {}".format(y.shape))
# Out:
# ====================================================================================================
# Number of training data samples-----> 1000
# Number of training features --------> 5
# Shape of the target value ----------> (1000, 1)

# %%
# display the data.
data = pd.DataFrame(X)
data.head()
# Out:
#           0         1         2         3         4
# 0  1.144411  0.635819  1.231175 -1.596560  0.286784
# 1  0.695890  0.342868  0.076991 -1.181580  0.330044
# 2 -2.149858 -1.470262  0.378865  1.670828  0.442422
# 3 -0.774470 -0.691267 -0.536714 -0.176460  0.734273
# 4  1.419312  1.019402 -0.481521 -0.868264 -0.465502

# %%
# display the data.
data_y = pd.DataFrame(y)
data_y.head()
# Out:
#    0
# 0  0
# 1  0
# 2  1
# 3  0
# 4  0

# %%
#define the parameters
sys.setrecursionlimit(2000)
param = {
    "n_neibours" : 5
}
print("="*100)
decirion_tree_cla = DecisionTreeClassifier(min_sample_split=2, max_depth=45)

# Train the model.
decirion_tree_cla.train(X, y) 
# print the decision tree.
print("Printing the tree :).....")
decirion_tree_cla.draw_tree()
# Predict the values.
y_pred = decirion_tree_cla.predict(X)

#calculate accuracy.
acc = np.sum(y==y_pred)/X.shape[0]
print("="*100)
print("Accuracy of the prediction is {}".format(acc))
# Out:
# ====================================================================================================
# Printing the tree :).....
#   Is 3>=0.10844009387345555?
#  ----- True branch :)
#     Is 3>=0.6625985670452765?
#    ----- True branch :)
#       Is 0>=-0.4054042127814852?
#      ----- True branch :)
#         Is 3>=1.2203038237394699?
#        ----- True branch :)
#           The predicted value --> 0.0
#        ----- False branch :)
#           Is 1>=0.16329762843211726?
#          ----- True branch :)
#             Is 2>=0.8991560084264173?
#            ----- True branch :)
#               The predicted value --> 1.0
#            ----- False branch :)
#               Is 2>=0.8519969563863656?
#              ----- True branch :)
#                 The predicted value --> 0.0
#              ----- False branch :)
#                 Is 3>=0.7812085237136166?
#                ----- True branch :)
#                   Is 4>=-1.7019746576197736?
#                  ----- True branch :)
#                     Is 3>=0.9639368013980331?
#                    ----- True branch :)
#                       Is 2>=-0.15617381831941574?
#                      ----- True branch :)
#                         The predicted value --> 1.0
#                      ----- False branch :)
#                         Is 2>=-0.17815034033450122?
#                        ----- True branch :)
#                           The predicted value --> 0.0
#                        ----- False branch :)
#                           Is 3>=1.105109392137889?
#                          ----- True branch :)
#                             Is 0>=0.44849468737059495?
#                            ----- True branch :)
#                               The predicted value --> 0.0
#                            ----- False branch :)
#                               The predicted value --> 1.0
#                          ----- False branch :)
#                             The predicted value --> 1.0
#                    ----- False branch :)
#                       Is 2>=0.5405430267841206?
#                      ----- True branch :)
#                         The predicted value --> 1.0
#                      ----- False branch :)
#                         Is 0>=1.2545787004001538?
#                        ----- True branch :)
#                           Is 0>=1.2751729308910194?
#                          ----- True branch :)
#                             The predicted value --> 0.0
#                          ----- False branch :)
#                             The predicted value --> 1.0
#                        ----- False branch :)
#                           The predicted value --> 0.0
#                  ----- False branch :)
#                     The predicted value --> 1.0
#                ----- False branch :)
#                   Is 0>=2.51711036936548?
#                  ----- True branch :)
#                     The predicted value --> 1.0
#                  ----- False branch :)
#                     The predicted value --> 0.0
#          ----- False branch :)
#             Is 0>=-0.21245944625191904?
#            ----- True branch :)
#               The predicted value --> 0.0
#            ----- False branch :)
#               Is 1>=-0.10754546576017521?
#              ----- True branch :)
#                 Is 0>=-0.28501672004629164?
#                ----- True branch :)
#                   The predicted value --> 1.0
#                ----- False branch :)
#                   Is 0>=-0.2903980093129558?
#                  ----- True branch :)
#                     The predicted value --> 0.0
#                  ----- False branch :)
#                     The predicted value --> 1.0
#              ----- False branch :)
#                 The predicted value --> 0.0
#      ----- False branch :)
#         Is 2>=-0.6960147844050439?
#        ----- True branch :)
#           The predicted value --> 1.0
#        ----- False branch :)
#           Is 2>=-0.8150799752055873?
#          ----- True branch :)
#             Is 0>=-0.9276857879209722?
#            ----- True branch :)
#               The predicted value --> 0.0
#            ----- False branch :)
#               Is 2>=-0.7386456434621176?
#              ----- True branch :)
#                 The predicted value --> 0.0
#              ----- False branch :)
#                 The predicted value --> 1.0
#          ----- False branch :)
#             The predicted value --> 1.0
#    ----- False branch :)
#       Is 4>=-0.49472382949582555?
#      ----- True branch :)
#         Is 0>=-0.26400736549575?
#        ----- True branch :)
#           Is 2>=-0.9388205444823718?
#          ----- True branch :)
#             Is 4>=-0.3151803613626348?
#            ----- True branch :)
#               The predicted value --> 1.0
#            ----- False branch :)
#               Is 4>=-0.3963168426465553?
#              ----- True branch :)
#                 Is 2>=-0.11204178877685236?
#                ----- True branch :)
#                   The predicted value --> 0.0
#                ----- False branch :)
#                   The predicted value --> 1.0
#              ----- False branch :)
#                 The predicted value --> 1.0
#          ----- False branch :)
#             Is 3>=0.3618770661334323?
#            ----- True branch :)
#               The predicted value --> 0.0
#            ----- False branch :)
#               The predicted value --> 1.0
#        ----- False branch :)
#           Is 3>=0.4745250761297515?
#          ----- True branch :)
#             Is 0>=-0.4124696037205873?
#            ----- True branch :)
#               Is 2>=-0.37720049579796283?
#              ----- True branch :)
#                 Is 2>=1.5639033066617993?
#                ----- True branch :)
#                   The predicted value --> 1.0
#                ----- False branch :)
#                   The predicted value --> 0.0
#              ----- False branch :)
#                 Is 1>=-0.12563595388279133?
#                ----- True branch :)
#                   The predicted value --> 0.0
#                ----- False branch :)
#                   The predicted value --> 1.0
#            ----- False branch :)
#               The predicted value --> 1.0
#          ----- False branch :)
#             Is 2>=0.27665902723945773?
#            ----- True branch :)
#               The predicted value --> 0.0
#            ----- False branch :)
#               Is 2>=0.26283165606559733?
#              ----- True branch :)
#                 The predicted value --> 1.0
#              ----- False branch :)
#                 Is 0>=-0.4949425388893597?
#                ----- True branch :)
#                   The predicted value --> 0.0
#                ----- False branch :)
#                   Is 0>=-0.5180074713698362?
#                  ----- True branch :)
#                     The predicted value --> 1.0
#                  ----- False branch :)
#                     The predicted value --> 0.0
#      ----- False branch :)
#         The predicted value --> 0.0
#  ----- False branch :)
#     Is 4>=-0.014164049643625335?
#    ----- True branch :)
#       Is 1>=-2.148452695689146?
#      ----- True branch :)
#         Is 2>=-1.088377137078335?
#        ----- True branch :)
#           The predicted value --> 0.0
#        ----- False branch :)
#           Is 2>=-1.090234418707646?
#          ----- True branch :)
#             The predicted value --> 1.0
#          ----- False branch :)
#             The predicted value --> 0.0
#      ----- False branch :)
#         Is 0>=-1.8141961616034195?
#        ----- True branch :)
#           The predicted value --> 1.0
#        ----- False branch :)
#           The predicted value --> 0.0
#    ----- False branch :)
#       Is 0>=0.5075382217032316?
#      ----- True branch :)
#         Is 0>=1.651985520319801?
#        ----- True branch :)
#           The predicted value --> 0.0
#        ----- False branch :)
#           Is 4>=-0.2635585144224221?
#          ----- True branch :)
#             The predicted value --> 0.0
#          ----- False branch :)
#             Is 4>=-0.5423016331827686?
#            ----- True branch :)
#               Is 3>=-0.34863710057264585?
#              ----- True branch :)
#                 Is 2>=-1.053915782021057?
#                ----- True branch :)
#                   The predicted value --> 1.0
#                ----- False branch :)
#                   The predicted value --> 0.0
#              ----- False branch :)
#                 Is 4>=-0.49404037554504543?
#                ----- True branch :)
#                   The predicted value --> 0.0
#                ----- False branch :)
#                   Is 0>=1.0596501456779204?
#                  ----- True branch :)
#                     The predicted value --> 1.0
#                  ----- False branch :)
#                     The predicted value --> 0.0
#            ----- False branch :)
#               Is 2>=0.726983229276548?
#              ----- True branch :)
#                 Is 2>=1.1629833796348041?
#                ----- True branch :)
#                   The predicted value --> 0.0
#                ----- False branch :)
#                   Is 3>=-0.5736250308656803?
#                  ----- True branch :)
#                     The predicted value --> 1.0
#                  ----- False branch :)
#                     The predicted value --> 0.0
#              ----- False branch :)
#                 The predicted value --> 0.0
#      ----- False branch :)
#         Is 2>=-0.6383572193238897?
#        ----- True branch :)
#           The predicted value --> 1.0
#        ----- False branch :)
#           Is 2>=-0.92082932818426?
#          ----- True branch :)
#             The predicted value --> 0.0
#          ----- False branch :)
#             The predicted value --> 1.0
# ====================================================================================================
# Accuracy of the prediction is 1.0

# %% [markdown]
# # Decision tree classifier using scikit-learn for comaprision.

# %%
from sklearn.tree import DecisionTreeClassifier as DecisionTreeClassifier_sklearn

# %%
# data is already defined, going to use the same data for comparision.
print("="*100)
print("Number of training data samples-----> {}".format(X.shape[0]))
print("Number of training features --------> {}".format(X.shape[1]))
# Out:
# ====================================================================================================
# Number of training data samples-----> 1000
# Number of training features --------> 5

# %%
decision_tree_sklearn = DecisionTreeClassifier_sklearn()
decision_tree_sklearn.fit(X, y)

# predict the value
y_pred_sklearn = decision_tree_sklearn.predict(X)
acc = accuracy_score(y, y_pred_sklearn)
print("="*100)
print("Accuracy of the prediction is {}".format(acc))
# Out:
# ====================================================================================================
# Accuracy of the prediction is 1.0

# %% [markdown]
# # Decision Tree Regression.

# %%
class DecisionTreeRegression(DecisionTree):
    """ Decision Tree for the classification problem."""
    def __init__(self, min_sample_split=3, min_impurity=1e-7, max_depth=float('inf'),
                 ):
        """
        :param min_sample_split: min value a leaf node must have.
        :param min_impurity: minimum impurity.
        :param max_depth: maximum depth of the tree.
        """
        self._impurity_function = self._claculate_variance_reduction
        self._leaf_value_calculation = self._calculate_colum_mean
        super(DecisionTreeRegression, self).__init__(min_sample_split=min_sample_split, min_impurity=min_impurity, max_depth=max_depth,
                         impurity_function=self._impurity_function, leaf_node_calculation=self._leaf_value_calculation)
    

    def _claculate_variance_reduction(self, y, y1, y2):
        """
        Calculate the Variance reduction.

        :param y: target value.
        :param y1: target value for dataset in the true split/right branch.
        :param y2: target value for dataset in the false split/left branch.
        """
        # propobility of true values.
        variance = np.var(y)
        variance_y1 = np.var(y1)
        variance_y2 = np.var(y2)

        y_len = len(y)
        fraction_1 = len(y1) / y_len 
        fraction_2 = len(y2) / y_len
        variance_reduction = variance - (fraction_1 * variance_y1 + fraction_2 * variance_y2)
        return  variance_reduction

    def _calculate_colum_mean(self, y):
        """
        calculate the prediction value for that leaf node using mean.
        
        :param y: leaf node target array.
        """
        mean = np.mean(y, axis=0)
        return mean

    def train(self, X, y):
        """
        Build the tree.

        :param X: Feature array/depentant values.
        :parma y: target array/indepentant values.
        """
        # train the model.
        super(DecisionTreeRegression, self).train(X, y)

# %% [markdown]
# # create the data.

# %%
# Define the traning data.
X, y = make_regression(n_samples=1000, n_features=8)

# Chnage the shape of the target to 1 dimentional array.
y = y[:, np.newaxis]

print("="*100)
print("Number of training data samples-----> {}".format(X.shape[0]))
print("Number of training features --------> {}".format(X.shape[1]))
print("Shape of the target value ----------> {}".format(y.shape))
# Out:
# ====================================================================================================
# Number of training data samples-----> 1000
# Number of training features --------> 8
# Shape of the target value ----------> (1000, 1)

# %%
# display the data.
data_y = pd.DataFrame(y)
data_y.head()
# Out:
#             0
# 0 -175.875302
# 1   11.975383
# 2  145.453963
# 3 -200.416922
# 4   73.861236

# %%
#define the parameters
sys.setrecursionlimit(2000)

print("="*100)
decirion_tree_reg = DecisionTreeRegression(min_sample_split=2, max_depth=45)

# Train the model.
decirion_tree_reg.train(X, y) 
print("Printing the mdoel :)...")
decirion_tree_reg.draw_tree()
# Predict the values.
y_pred = decirion_tree_reg.predict(X)
#Root mean square error.
score = r2_score(y, y_pred)
print("The r2_score of the trained model", score)
# Out:
# ====================================================================================================
# Printing the mdoel :)...
#   Is 0>=-0.18619472096979606?
#  ----- True branch :)
#     Is 6>=-0.08996100091258548?
#    ----- True branch :)
#       Is 0>=0.7287433527667087?
#      ----- True branch :)
#         Is 0>=2.0601637307064706?
#        ----- True branch :)
#           Is 0>=2.49134974947138?
#          ----- True branch :)
#             Is 3>=0.9359451692976996?
#            ----- True branch :)
#               The predicted value --> [468.6795565]
#            ----- False branch :)
#               Is 0>=2.5808000012991066?
#              ----- True branch :)
#                 Is 0>=3.1717970990430193?
#                ----- True branch :)
#                   The predicted value --> [334.4191281]
#                ----- False branch :)
#                   The predicted value --> [348.28893673]
#              ----- False branch :)
#                 The predicted value --> [377.60470119]
#          ----- False branch :)
#             Is 3>=0.16703952217337248?
#            ----- True branch :)
#               Is 0>=2.060411101701903?
#              ----- True branch :)
#                 Is 4>=-0.05361391016043553?
#                ----- True branch :)
#                   Is 2>=-0.1959263807536545?
#                  ----- True branch :)
#                     Is 0>=2.273160824837202?
#                    ----- True branch :)
#                       The predicted value --> [359.53484857]
#                    ----- False branch :)
#                       Is 0>=2.2421117355654463?
#                      ----- True branch :)
#                         The predicted value --> [323.76424191]
#                      ----- False branch :)
#                         The predicted value --> [303.12978197]
#                  ----- False branch :)
#                     The predicted value --> [252.55415922]
#                ----- False branch :)
#                   Is 1>=0.3312514808194762?
#                  ----- True branch :)
#                     Is 0>=2.3631809043454433?
#                    ----- True branch :)
#                       The predicted value --> [246.36230639]
#                    ----- False branch :)
#                       The predicted value --> [218.79831189]
#                  ----- False branch :)
#                     The predicted value --> [189.8020859]
#              ----- False branch :)
#                 The predicted value --> [421.86618246]
#            ----- False branch :)
#               Is 3>=-1.2491228795251856?
#              ----- True branch :)
#                 Is 3>=-0.0017979058639093029?
#                ----- True branch :)
#                   The predicted value --> [155.70914889]
#                ----- False branch :)
#                   Is 0>=2.2791154667235105?
#                  ----- True branch :)
#                     The predicted value --> [174.40417449]
#                  ----- False branch :)
#                     Is 0>=2.2076015074133766?
#                    ----- True branch :)
#                       The predicted value --> [173.32806242]
#                    ----- False branch :)
#                       The predicted value --> [172.73094799]
#              ----- False branch :)
#                 Is 0>=2.136738778035442?
#                ----- True branch :)
#                   The predicted value --> [188.12171496]
#                ----- False branch :)
#                   The predicted value --> [193.55953218]
#        ----- False branch :)
#           Is 7>=-0.9318440543212431?
#          ----- True branch :)
#             Is 4>=-0.6951822910859632?
#            ----- True branch :)
#               Is 6>=0.6335557599186709?
#              ----- True branch :)
#                 Is 1>=-0.19498550451573382?
#                ----- True branch :)
#                   Is 2>=-1.1942077053358713?
#                  ----- True branch :)
#                     Is 0>=1.0150041962799807?
#                    ----- True branch :)
#                       Is 5>=-0.4846187194030541?
#                      ----- True branch :)
#                         Is 7>=-0.4862913005407591?
#                        ----- True branch :)
#                           Is 6>=0.9473075497194581?
#                          ----- True branch :)
#                             Is 3>=0.491988621134177?
#                            ----- True branch :)
#                               Is 2>=-0.23071932008513485?
#                              ----- True branch :)
#                                 Is 0>=1.0617303232006796?
#                                ----- True branch :)
#                                   Is 0>=1.2887616338126264?
#                                  ----- True branch :)
#                                     The predicted value --> [280.76852221]
#                                  ----- False branch :)
#                                     The predicted value --> [277.75682806]
#                                ----- False branch :)
#                                   The predicted value --> [287.90261214]
#                              ----- False branch :)
#                                 Is 0>=1.6077519347132547?
#                                ----- True branch :)
#                                   The predicted value --> [263.01111208]
#                                ----- False branch :)
#                                   The predicted value --> [266.53575416]
#                            ----- False branch :)
#                               Is 0>=1.8990016062936343?
#                              ----- True branch :)
#                                 The predicted value --> [336.66921098]
#                              ----- False branch :)
#                                 Is 4>=2.0375243222803623?
#                                ----- True branch :)
#                                   The predicted value --> [329.2724929]
#                                ----- False branch :)
#                                   Is 0>=1.6835503172890613?
#                                  ----- True branch :)
#                                     The predicted value --> [291.2068128]
#                                  ----- False branch :)
#                                     Is 0>=1.4282510158928972?
#                                    ----- True branch :)
#                                       The predicted value --> [295.65556756]
#                                    ----- False branch :)
#                                       The predicted value --> [295.02731076]
#                          ----- False branch :)
#                             The predicted value --> [237.92705195]
#                        ----- False branch :)
#                           Is 0>=1.488436657732977?
#                          ----- True branch :)
#                             The predicted value --> [218.6115688]
#                          ----- False branch :)
#                             The predicted value --> [249.7070665]
#                      ----- False branch :)
#                         The predicted value --> [175.85222212]
#                    ----- False branch :)
#                       Is 6>=1.328485747357654?
#                      ----- True branch :)
#                         Is 0>=0.9918496012100317?
#                        ----- True branch :)
#                           The predicted value --> [240.71185557]
#                        ----- False branch :)
#                           The predicted value --> [224.46253343]
#                      ----- False branch :)
#                         Is 0>=0.7402189829705259?
#                        ----- True branch :)
#                           Is 0>=0.9474196267777638?
#                          ----- True branch :)
#                             Is 0>=1.0085557243364023?
#                            ----- True branch :)
#                               The predicted value --> [186.65129926]
#                            ----- False branch :)
#                               The predicted value --> [192.87786218]
#                          ----- False branch :)
#                             Is 3>=0.5272388223545205?
#                            ----- True branch :)
#                               Is 0>=0.7804776264199107?
#                              ----- True branch :)
#                                 The predicted value --> [197.69346484]
#                              ----- False branch :)
#                                 The predicted value --> [196.1737908]
#                            ----- False branch :)
#                               Is 0>=0.8728722071308413?
#                              ----- True branch :)
#                                 The predicted value --> [200.88935341]
#                              ----- False branch :)
#                                 The predicted value --> [201.35075076]
#                        ----- False branch :)
#                           The predicted value --> [232.50044271]
#                  ----- False branch :)
#                     Is 4>=0.36480967483346144?
#                    ----- True branch :)
#                       Is 0>=1.5426131191542665?
#                      ----- True branch :)
#                         The predicted value --> [138.79523461]
#                      ----- False branch :)
#                         The predicted value --> [136.55570603]
#                    ----- False branch :)
#                       The predicted value --> [215.75068712]
#                ----- False branch :)
#                   Is 4>=1.80868516590277?
#                  ----- True branch :)
#                     Is 0>=1.4405092724553212?
#                    ----- True branch :)
#                       Is 0>=1.4757135483173662?
#                      ----- True branch :)
#                         The predicted value --> [219.69783518]
#                      ----- False branch :)
#                         The predicted value --> [238.35049823]
#                    ----- False branch :)
#                       The predicted value --> [268.75387824]
#                  ----- False branch :)
#                     Is 1>=-0.3631965076364666?
#                    ----- True branch :)
#                       Is 0>=0.9226311076511343?
#                      ----- True branch :)
#                         The predicted value --> [108.11953935]
#                      ----- False branch :)
#                         The predicted value --> [115.69690915]
#                    ----- False branch :)
#                       Is 2>=0.6062487543390847?
#                      ----- True branch :)
#                         The predicted value --> [125.84815453]
#                      ----- False branch :)
#                         Is 4>=0.19938305270313786?
#                        ----- True branch :)
#                           Is 0>=1.6622897670935821?
#                          ----- True branch :)
#                             The predicted value --> [169.89479047]
#                          ----- False branch :)
#                             Is 0>=1.2031651034138415?
#                            ----- True branch :)
#                               The predicted value --> [178.02859701]
#                            ----- False branch :)
#                               The predicted value --> [174.71953811]
#                        ----- False branch :)
#                           Is 0>=1.1981767051104124?
#                          ----- True branch :)
#                             The predicted value --> [187.57812372]
#                          ----- False branch :)
#                             The predicted value --> [185.13243196]
#              ----- False branch :)
#                 Is 2>=-1.7954434278793614?
#                ----- True branch :)
#                   Is 7>=0.5074268199823655?
#                  ----- True branch :)
#                     Is 4>=-0.2091438989793453?
#                    ----- True branch :)
#                       Is 5>=0.22185254738692906?
#                      ----- True branch :)
#                         Is 1>=1.2314544291197305?
#                        ----- True branch :)
#                           Is 0>=1.2346452587992618?
#                          ----- True branch :)
#                             Is 0>=1.39569450428754?
#                            ----- True branch :)
#                               The predicted value --> [230.38317592]
#                            ----- False branch :)
#                               The predicted value --> [249.75796935]
#                          ----- False branch :)
#                             The predicted value --> [269.25707837]
#                        ----- False branch :)
#                           Is 2>=0.5191076950635563?
#                          ----- True branch :)
#                             Is 0>=0.8961310750930553?
#                            ----- True branch :)
#                               The predicted value --> [239.08149354]
#                            ----- False branch :)
#                               The predicted value --> [227.49402606]
#                          ----- False branch :)
#                             Is 4>=0.6835813290326419?
#                            ----- True branch :)
#                               Is 0>=1.0889635296027422?
#                              ----- True branch :)
#                                 Is 0>=1.782550611249202?
#                                ----- True branch :)
#                                   The predicted value --> [205.62060424]
#                                ----- False branch :)
#                                   The predicted value --> [208.61280928]
#                              ----- False branch :)
#                                 The predicted value --> [201.7181932]
#                            ----- False branch :)
#                               The predicted value --> [218.13288109]
#                      ----- False branch :)
#                         Is 0>=1.505231559932481?
#                        ----- True branch :)
#                           Is 0>=2.0018488840309265?
#                          ----- True branch :)
#                             The predicted value --> [197.44830012]
#                          ----- False branch :)
#                             The predicted value --> [193.42379555]
#                        ----- False branch :)
#                           Is 0>=1.1536845956709882?
#                          ----- True branch :)
#                             The predicted value --> [171.77073416]
#                          ----- False branch :)
#                             The predicted value --> [168.48390649]
#                    ----- False branch :)
#                       Is 0>=1.1441005962963262?
#                      ----- True branch :)
#                         Is 0>=2.0043721529511793?
#                        ----- True branch :)
#                           The predicted value --> [176.93066543]
#                        ----- False branch :)
#                           The predicted value --> [204.21584158]
#                      ----- False branch :)
#                         Is 0>=0.9582770281196026?
#                        ----- True branch :)
#                           The predicted value --> [125.15655934]
#                        ----- False branch :)
#                           The predicted value --> [119.51187555]
#                  ----- False branch :)
#                     Is 2>=0.33038568702834054?
#                    ----- True branch :)
#                       Is 3>=-0.773203422854579?
#                      ----- True branch :)
#                         Is 3>=0.17628861318538808?
#                        ----- True branch :)
#                           Is 1>=-0.8686017641445097?
#                          ----- True branch :)
#                             Is 1>=-0.4518967703505318?
#                            ----- True branch :)
#                               Is 0>=1.8860136450331377?
#                              ----- True branch :)
#                                 The predicted value --> [177.27416021]
#                              ----- False branch :)
#                                 The predicted value --> [187.36608243]
#                            ----- False branch :)
#                               Is 0>=1.4657462614409917?
#                              ----- True branch :)
#                                 The predicted value --> [207.4200164]
#                              ----- False branch :)
#                                 The predicted value --> [213.93897796]
#                          ----- False branch :)
#                             Is 0>=1.220438551031293?
#                            ----- True branch :)
#                               Is 0>=1.240127039201402?
#                              ----- True branch :)
#                                 The predicted value --> [170.44698017]
#                              ----- False branch :)
#                                 The predicted value --> [169.38944953]
#                            ----- False branch :)
#                               The predicted value --> [173.77962717]
#                        ----- False branch :)
#                           Is 0>=1.4396114384122694?
#                          ----- True branch :)
#                             The predicted value --> [242.79237028]
#                          ----- False branch :)
#                             The predicted value --> [223.61465589]
#                      ----- False branch :)
#                         Is 0>=0.9896731425643728?
#                        ----- True branch :)
#                           Is 0>=1.8612993247264387?
#                          ----- True branch :)
#                             The predicted value --> [154.84420707]
#                          ----- False branch :)
#                             The predicted value --> [147.06684572]
#                        ----- False branch :)
#                           The predicted value --> [167.24860987]
#                    ----- False branch :)
#                       Is 3>=0.11417905451036113?
#                      ----- True branch :)
#                         Is 0>=0.791453465941373?
#                        ----- True branch :)
#                           Is 2>=-0.11071795200888226?
#                          ----- True branch :)
#                             Is 0>=1.024449350568375?
#                            ----- True branch :)
#                               The predicted value --> [154.34351534]
#                            ----- False branch :)
#                               The predicted value --> [163.91991754]
#                          ----- False branch :)
#                             Is 0>=1.1538288954706348?
#                            ----- True branch :)
#                               Is 0>=1.3775058115145067?
#                              ----- True branch :)
#                                 The predicted value --> [148.29680213]
#                              ----- False branch :)
#                                 The predicted value --> [148.79354007]
#                            ----- False branch :)
#                               Is 0>=0.8002717557333325?
#                              ----- True branch :)
#                                 The predicted value --> [142.40724024]
#                              ----- False branch :)
#                                 The predicted value --> [140.94929813]
#                        ----- False branch :)
#                           The predicted value --> [173.17575365]
#                      ----- False branch :)
#                         Is 4>=0.7477568440136159?
#                        ----- True branch :)
#                           Is 3>=-1.2737938937603943?
#                          ----- True branch :)
#                             Is 0>=1.422819813664869?
#                            ----- True branch :)
#                               The predicted value --> [134.39535002]
#                            ----- False branch :)
#                               The predicted value --> [123.75742546]
#                          ----- False branch :)
#                             The predicted value --> [154.73544346]
#                        ----- False branch :)
#                           Is 0>=1.3503107273657577?
#                          ----- True branch :)
#                             Is 3>=-0.5227388231934869?
#                            ----- True branch :)
#                               The predicted value --> [94.98798101]
#                            ----- False branch :)
#                               Is 0>=1.8127877067986757?
#                              ----- True branch :)
#                                 The predicted value --> [115.4684067]
#                              ----- False branch :)
#                                 The predicted value --> [106.7985991]
#                          ----- False branch :)
#                             Is 0>=1.1369910886344807?
#                            ----- True branch :)
#                               The predicted value --> [71.35747833]
#                            ----- False branch :)
#                               The predicted value --> [63.68540624]
#                ----- False branch :)
#                   Is 0>=1.4898442390976532?
#                  ----- True branch :)
#                     The predicted value --> [76.86412541]
#                  ----- False branch :)
#                     The predicted value --> [6.1940601]
#            ----- False branch :)
#               Is 3>=0.602578239609772?
#              ----- True branch :)
#                 Is 0>=1.1364918584281734?
#                ----- True branch :)
#                   Is 0>=1.5868356481011112?
#                  ----- True branch :)
#                     The predicted value --> [198.13441055]
#                  ----- False branch :)
#                     The predicted value --> [207.6504882]
#                ----- False branch :)
#                   Is 0>=1.1269484433432233?
#                  ----- True branch :)
#                     The predicted value --> [151.30455749]
#                  ----- False branch :)
#                     The predicted value --> [158.4280755]
#              ----- False branch :)
#                 Is 1>=1.5351276609432598?
#                ----- True branch :)
#                   Is 0>=1.6667418401783474?
#                  ----- True branch :)
#                     The predicted value --> [133.80975988]
#                  ----- False branch :)
#                     The predicted value --> [165.35965367]
#                ----- False branch :)
#                   Is 2>=-1.4736253791407696?
#                  ----- True branch :)
#                     Is 7>=-0.40012003894128134?
#                    ----- True branch :)
#                       Is 1>=-1.0059531038186824?
#                      ----- True branch :)
#                         Is 7>=1.4019452645350068?
#                        ----- True branch :)
#                           Is 0>=0.9013631844169832?
#                          ----- True branch :)
#                             The predicted value --> [65.82798908]
#                          ----- False branch :)
#                             The predicted value --> [60.90947706]
#                        ----- False branch :)
#                           Is 4>=-1.4902085217700047?
#                          ----- True branch :)
#                             Is 4>=-0.7943763047693745?
#                            ----- True branch :)
#                               The predicted value --> [105.52920189]
#                            ----- False branch :)
#                               Is 1>=0.29427388631617224?
#                              ----- True branch :)
#                                 Is 1>=0.9068227769478616?
#                                ----- True branch :)
#                                   Is 0>=1.9336580415419293?
#                                  ----- True branch :)
#                                     The predicted value --> [89.1649394]
#                                  ----- False branch :)
#                                     The predicted value --> [90.51775332]
#                                ----- False branch :)
#                                   Is 0>=1.6222435204445924?
#                                  ----- True branch :)
#                                     The predicted value --> [87.8496293]
#                                  ----- False branch :)
#                                     The predicted value --> [87.09881642]
#                              ----- False branch :)
#                                 Is 0>=1.455538134756871?
#                                ----- True branch :)
#                                   The predicted value --> [95.3250645]
#                                ----- False branch :)
#                                   The predicted value --> [95.32841845]
#                          ----- False branch :)
#                             The predicted value --> [64.94122515]
#                      ----- False branch :)
#                         Is 0>=0.7845174981265474?
#                        ----- True branch :)
#                           Is 0>=1.3710496763407587?
#                          ----- True branch :)
#                             The predicted value --> [128.79891164]
#                          ----- False branch :)
#                             The predicted value --> [114.50499232]
#                        ----- False branch :)
#                           The predicted value --> [84.98465824]
#                    ----- False branch :)
#                       Is 1>=0.080184955896399?
#                      ----- True branch :)
#                         Is 0>=1.5808631726219207?
#                        ----- True branch :)
#                           The predicted value --> [119.92887136]
#                        ----- False branch :)
#                           The predicted value --> [114.60804754]
#                      ----- False branch :)
#                         The predicted value --> [135.26509398]
#                  ----- False branch :)
#                     The predicted value --> [28.28607099]
#          ----- False branch :)
#             Is 5>=-0.1386362112329013?
#            ----- True branch :)
#               Is 5>=0.24202673675474065?
#              ----- True branch :)
#                 Is 6>=1.5903792986070122?
#                ----- True branch :)
#                   Is 0>=1.2214379954229202?
#                  ----- True branch :)
#                     The predicted value --> [96.11127688]
#                  ----- False branch :)
#                     The predicted value --> [96.58349774]
#                ----- False branch :)
#                   Is 1>=0.7153963755793378?
#                  ----- True branch :)
#                     The predicted value --> [35.6522142]
#                  ----- False branch :)
#                     Is 0>=1.4416035066674897?
#                    ----- True branch :)
#                       The predicted value --> [80.96795262]
#                    ----- False branch :)
#                       Is 2>=0.40163724412664675?
#                      ----- True branch :)
#                         The predicted value --> [50.71512908]
#                      ----- False branch :)
#                         Is 0>=0.8844826025829883?
#                        ----- True branch :)
#                           The predicted value --> [65.91458885]
#                        ----- False branch :)
#                           The predicted value --> [62.52138181]
#              ----- False branch :)
#                 Is 0>=1.2141751391389546?
#                ----- True branch :)
#                   Is 0>=1.8533940137828366?
#                  ----- True branch :)
#                     The predicted value --> [147.70600023]
#                  ----- False branch :)
#                     Is 0>=1.79860930876433?
#                    ----- True branch :)
#                       The predicted value --> [112.00307981]
#                    ----- False branch :)
#                       The predicted value --> [124.11556782]
#                ----- False branch :)
#                   The predicted value --> [186.43573851]
#            ----- False branch :)
#               Is 7>=-2.161013808700367?
#              ----- True branch :)
#                 Is 3>=-1.3964852298146853?
#                ----- True branch :)
#                   Is 2>=1.6805889626675103?
#                  ----- True branch :)
#                     The predicted value --> [32.94150418]
#                  ----- False branch :)
#                     Is 1>=0.9534314866400854?
#                    ----- True branch :)
#                       The predicted value --> [-0.90873864]
#                    ----- False branch :)
#                       Is 0>=1.530077352860203?
#                      ----- True branch :)
#                         The predicted value --> [10.56470238]
#                      ----- False branch :)
#                         Is 0>=0.7708904198514945?
#                        ----- True branch :)
#                           The predicted value --> [16.10939929]
#                        ----- False branch :)
#                           The predicted value --> [18.41864196]
#                ----- False branch :)
#                   Is 0>=1.6843368440853623?
#                  ----- True branch :)
#                     The predicted value --> [57.14130581]
#                  ----- False branch :)
#                     The predicted value --> [39.36384118]
#              ----- False branch :)
#                 The predicted value --> [120.03641956]
#      ----- False branch :)
#         Is 4>=0.1530793067677835?
#        ----- True branch :)
#           Is 6>=0.9250768190181556?
#          ----- True branch :)
#             Is 3>=-1.973408581137797?
#            ----- True branch :)
#               Is 7>=1.1115761700678608?
#              ----- True branch :)
#                 Is 3>=1.403670809414977?
#                ----- True branch :)
#                   Is 0>=0.6741854500916666?
#                  ----- True branch :)
#                     The predicted value --> [270.97247422]
#                  ----- False branch :)
#                     The predicted value --> [245.39527693]
#                ----- False branch :)
#                   Is 0>=0.6222670957375812?
#                  ----- True branch :)
#                     The predicted value --> [315.31517791]
#                  ----- False branch :)
#                     The predicted value --> [307.12387679]
#              ----- False branch :)
#                 Is 2>=1.725266539617853?
#                ----- True branch :)
#                   Is 1>=-0.38920027601786766?
#                  ----- True branch :)
#                     Is 0>=0.48987907625676147?
#                    ----- True branch :)
#                       The predicted value --> [235.03605334]
#                    ----- False branch :)
#                       The predicted value --> [233.22220566]
#                  ----- False branch :)
#                     The predicted value --> [286.66849636]
#                ----- False branch :)
#                   Is 6>=1.489285782044864?
#                  ----- True branch :)
#                     Is 7>=0.00018900573837626653?
#                    ----- True branch :)
#                       Is 1>=-0.731153235557242?
#                      ----- True branch :)
#                         Is 0>=-0.082469916864899?
#                        ----- True branch :)
#                           Is 0>=0.5229136820270509?
#                          ----- True branch :)
#                             The predicted value --> [207.09812992]
#                          ----- False branch :)
#                             The predicted value --> [204.01840713]
#                        ----- False branch :)
#                           The predicted value --> [200.21605905]
#                      ----- False branch :)
#                         Is 0>=0.3110662507321753?
#                        ----- True branch :)
#                           The predicted value --> [195.09264059]
#                        ----- False branch :)
#                           The predicted value --> [193.60087838]
#                    ----- False branch :)
#                       Is 0>=0.15556380523614377?
#                      ----- True branch :)
#                         Is 0>=0.44017735170547123?
#                        ----- True branch :)
#                           The predicted value --> [182.40867711]
#                        ----- False branch :)
#                           Is 0>=0.25441457364889314?
#                          ----- True branch :)
#                             The predicted value --> [173.65626927]
#                          ----- False branch :)
#                             The predicted value --> [175.69442303]
#                      ----- False branch :)
#                         The predicted value --> [164.44071003]
#                  ----- False branch :)
#                     Is 6>=1.4692308888268801?
#                    ----- True branch :)
#                       Is 0>=-0.016809123018067272?
#                      ----- True branch :)
#                         The predicted value --> [121.26158023]
#                      ----- False branch :)
#                         The predicted value --> [137.92250905]
#                    ----- False branch :)
#                       Is 2>=1.5158495430214467?
#                      ----- True branch :)
#                         The predicted value --> [194.81293869]
#                      ----- False branch :)
#                         Is 0>=-0.12592719246327458?
#                        ----- True branch :)
#                           Is 2>=1.16887885887358?
#                          ----- True branch :)
#                             The predicted value --> [157.73244226]
#                          ----- False branch :)
#                             Is 0>=0.43468305060044793?
#                            ----- True branch :)
#                               The predicted value --> [151.06145096]
#                            ----- False branch :)
#                               The predicted value --> [152.33923052]
#                        ----- False branch :)
#                           The predicted value --> [190.58465688]
#            ----- False branch :)
#               Is 0>=0.5785495670493226?
#              ----- True branch :)
#                 The predicted value --> [88.1865612]
#              ----- False branch :)
#                 The predicted value --> [-2.54307276]
#          ----- False branch :)
#             Is 7>=0.0008161483876476958?
#            ----- True branch :)
#               Is 0>=0.03318318093288814?
#              ----- True branch :)
#                 Is 0>=0.5429820272344879?
#                ----- True branch :)
#                   The predicted value --> [220.80694011]
#                ----- False branch :)
#                   Is 6>=0.8318276481008311?
#                  ----- True branch :)
#                     Is 0>=0.4385379398521169?
#                    ----- True branch :)
#                       The predicted value --> [120.66286941]
#                    ----- False branch :)
#                       The predicted value --> [109.46609842]
#                  ----- False branch :)
#                     Is 0>=0.17603420544554035?
#                    ----- True branch :)
#                       Is 0>=0.5415857343836139?
#                      ----- True branch :)
#                         The predicted value --> [130.3251816]
#                      ----- False branch :)
#                         Is 0>=0.3476311986024057?
#                        ----- True branch :)
#                           The predicted value --> [137.42367762]
#                        ----- False branch :)
#                           The predicted value --> [140.83454017]
#                    ----- False branch :)
#                       The predicted value --> [153.85639609]
#              ----- False branch :)
#                 Is 0>=-0.14726632147149127?
#                ----- True branch :)
#                   Is 2>=1.1012130070154296?
#                  ----- True branch :)
#                     Is 0>=-0.09883482526999043?
#                    ----- True branch :)
#                       The predicted value --> [102.18854073]
#                    ----- False branch :)
#                       The predicted value --> [107.24501559]
#                  ----- False branch :)
#                     Is 0>=-0.10114758759223766?
#                    ----- True branch :)
#                       The predicted value --> [86.20383442]
#                    ----- False branch :)
#                       The predicted value --> [86.28230283]
#                ----- False branch :)
#                   Is 0>=-0.15415379358182282?
#                  ----- True branch :)
#                     The predicted value --> [54.52232153]
#                  ----- False branch :)
#                     The predicted value --> [61.09773313]
#            ----- False branch :)
#               Is 0>=0.633650716432045?
#              ----- True branch :)
#                 Is 0>=0.7177986465526774?
#                ----- True branch :)
#                   The predicted value --> [97.49215315]
#                ----- False branch :)
#                   The predicted value --> [146.09356008]
#              ----- False branch :)
#                 Is 5>=1.7929322299026949?
#                ----- True branch :)
#                   The predicted value --> [108.88383375]
#                ----- False branch :)
#                   Is 1>=-1.5834819039927386?
#                  ----- True branch :)
#                     Is 4>=0.8593772764625136?
#                    ----- True branch :)
#                       Is 0>=0.019129028451747715?
#                      ----- True branch :)
#                         Is 0>=0.4588148078978956?
#                        ----- True branch :)
#                           The predicted value --> [8.83489246]
#                        ----- False branch :)
#                           The predicted value --> [2.17554171]
#                      ----- False branch :)
#                         Is 0>=0.014096000929305344?
#                        ----- True branch :)
#                           The predicted value --> [27.0705953]
#                        ----- False branch :)
#                           The predicted value --> [41.62029092]
#                    ----- False branch :)
#                       Is 0>=0.1833185112968809?
#                      ----- True branch :)
#                         Is 0>=0.3654122238042303?
#                        ----- True branch :)
#                           The predicted value --> [46.60564546]
#                        ----- False branch :)
#                           The predicted value --> [56.94633299]
#                      ----- False branch :)
#                         The predicted value --> [32.1015301]
#                  ----- False branch :)
#                     The predicted value --> [-30.63307893]
#        ----- False branch :)
#           Is 3>=0.2831332937705397?
#          ----- True branch :)
#             Is 7>=1.025856480832184?
#            ----- True branch :)
#               Is 0>=0.17367357691572183?
#              ----- True branch :)
#                 Is 0>=0.5419328486207776?
#                ----- True branch :)
#                   The predicted value --> [231.15993583]
#                ----- False branch :)
#                   Is 3>=1.6659832125219636?
#                  ----- True branch :)
#                     Is 0>=0.4939770704599784?
#                    ----- True branch :)
#                       The predicted value --> [188.89923603]
#                    ----- False branch :)
#                       The predicted value --> [206.06741603]
#                  ----- False branch :)
#                     Is 0>=0.4650141434360336?
#                    ----- True branch :)
#                       The predicted value --> [118.77384593]
#                    ----- False branch :)
#                       Is 0>=0.3596843582918881?
#                      ----- True branch :)
#                         Is 0>=0.3953812536133663?
#                        ----- True branch :)
#                           The predicted value --> [151.43925778]
#                        ----- False branch :)
#                           The predicted value --> [151.27357359]
#                      ----- False branch :)
#                         The predicted value --> [155.41246071]
#              ----- False branch :)
#                 Is 4>=-0.6201897024450609?
#                ----- True branch :)
#                   Is 0>=-0.028940338081778406?
#                  ----- True branch :)
#                     The predicted value --> [162.51654954]
#                  ----- False branch :)
#                     The predicted value --> [120.31906645]
#                ----- False branch :)
#                   Is 0>=-0.008684704998194667?
#                  ----- True branch :)
#                     The predicted value --> [53.32579564]
#                  ----- False branch :)
#                     The predicted value --> [91.45127728]
#            ----- False branch :)
#               Is 4>=-0.5794576622665033?
#              ----- True branch :)
#                 Is 1>=-1.2652619312979951?
#                ----- True branch :)
#                   Is 6>=1.5159175072653397?
#                  ----- True branch :)
#                     Is 0>=0.21584595755052652?
#                    ----- True branch :)
#                       Is 1>=-0.927770579967098?
#                      ----- True branch :)
#                         Is 0>=0.7129598861510471?
#                        ----- True branch :)
#                           The predicted value --> [151.14255014]
#                        ----- False branch :)
#                           The predicted value --> [144.32122501]
#                      ----- False branch :)
#                         The predicted value --> [161.06333576]
#                    ----- False branch :)
#                       The predicted value --> [128.29162587]
#                  ----- False branch :)
#                     Is 3>=0.9322318270151705?
#                    ----- True branch :)
#                       Is 1>=1.0060192408385569?
#                      ----- True branch :)
#                         Is 4>=0.11147827968170679?
#                        ----- True branch :)
#                           The predicted value --> [110.41434393]
#                        ----- False branch :)
#                           Is 0>=0.41492154049571983?
#                          ----- True branch :)
#                             The predicted value --> [137.50201837]
#                          ----- False branch :)
#                             The predicted value --> [136.67641755]
#                      ----- False branch :)
#                         Is 1>=-0.01965115219901076?
#                        ----- True branch :)
#                           Is 0>=0.7282441661803937?
#                          ----- True branch :)
#                             The predicted value --> [106.02328092]
#                          ----- False branch :)
#                             The predicted value --> [108.88719939]
#                        ----- False branch :)
#                           Is 0>=0.6264847755182864?
#                          ----- True branch :)
#                             The predicted value --> [115.85597999]
#                          ----- False branch :)
#                             The predicted value --> [111.78082984]
#                    ----- False branch :)
#                       Is 0>=0.13137161987032536?
#                      ----- True branch :)
#                         Is 3>=0.7614496558813798?
#                        ----- True branch :)
#                           Is 0>=0.6200625531274182?
#                          ----- True branch :)
#                             The predicted value --> [94.15645803]
#                          ----- False branch :)
#                             Is 0>=0.3653987870488616?
#                            ----- True branch :)
#                               The predicted value --> [90.93876863]
#                            ----- False branch :)
#                               The predicted value --> [88.58448574]
#                        ----- False branch :)
#                           Is 1>=0.8916932511591142?
#                          ----- True branch :)
#                             The predicted value --> [113.29223485]
#                          ----- False branch :)
#                             Is 0>=0.6236217952057419?
#                            ----- True branch :)
#                               The predicted value --> [102.25036892]
#                            ----- False branch :)
#                               The predicted value --> [105.49399209]
#                      ----- False branch :)
#                         The predicted value --> [71.90921194]
#                ----- False branch :)
#                   The predicted value --> [0.09978727]
#              ----- False branch :)
#                 Is 6>=0.8694355306819675?
#                ----- True branch :)
#                   Is 0>=0.20834731697924977?
#                  ----- True branch :)
#                     Is 1>=0.5850257748023265?
#                    ----- True branch :)
#                       Is 0>=0.4715546147639301?
#                      ----- True branch :)
#                         The predicted value --> [94.00118078]
#                      ----- False branch :)
#                         The predicted value --> [99.28615069]
#                    ----- False branch :)
#                       The predicted value --> [128.14986366]
#                  ----- False branch :)
#                     Is 0>=0.08979288291768318?
#                    ----- True branch :)
#                       The predicted value --> [40.50922603]
#                    ----- False branch :)
#                       The predicted value --> [65.56070001]
#                ----- False branch :)
#                   Is 0>=0.4400636271660121?
#                  ----- True branch :)
#                     Is 0>=0.6677017216496041?
#                    ----- True branch :)
#                       Is 0>=0.7062477096261228?
#                      ----- True branch :)
#                         The predicted value --> [58.27971451]
#                      ----- False branch :)
#                         The predicted value --> [48.63399715]
#                    ----- False branch :)
#                       The predicted value --> [94.61890842]
#                  ----- False branch :)
#                     Is 1>=-0.5502835064538873?
#                    ----- True branch :)
#                       Is 0>=0.36886543119149573?
#                      ----- True branch :)
#                         Is 0>=0.4098077302195443?
#                        ----- True branch :)
#                           The predicted value --> [28.75138432]
#                        ----- False branch :)
#                           The predicted value --> [21.33078181]
#                      ----- False branch :)
#                         Is 0>=0.11903620666579004?
#                        ----- True branch :)
#                           The predicted value --> [11.97538271]
#                        ----- False branch :)
#                           The predicted value --> [16.25226791]
#                    ----- False branch :)
#                       Is 0>=0.25046884814156545?
#                      ----- True branch :)
#                         The predicted value --> [1.60262971]
#                      ----- False branch :)
#                         The predicted value --> [-11.45345425]
#          ----- False branch :)
#             Is 7>=0.7057509009213473?
#            ----- True branch :)
#               Is 7>=2.171320827749865?
#              ----- True branch :)
#                 Is 0>=0.3591933105953467?
#                ----- True branch :)
#                   The predicted value --> [199.32870863]
#                ----- False branch :)
#                   Is 0>=0.02455167597890895?
#                  ----- True branch :)
#                     The predicted value --> [148.59343957]
#                  ----- False branch :)
#                     The predicted value --> [155.78845706]
#              ----- False branch :)
#                 Is 4>=-0.9548472715215586?
#                ----- True branch :)
#                   Is 2>=1.3009440051880712?
#                  ----- True branch :)
#                     Is 0>=0.7046205563803494?
#                    ----- True branch :)
#                       The predicted value --> [125.65941838]
#                    ----- False branch :)
#                       The predicted value --> [111.93626633]
#                  ----- False branch :)
#                     Is 6>=0.33557311571241666?
#                    ----- True branch :)
#                       Is 1>=0.5897313176046529?
#                      ----- True branch :)
#                         The predicted value --> [119.02879558]
#                      ----- False branch :)
# ...
#                             The predicted value --> [-158.05378581]
#              ----- False branch :)
#                 The predicted value --> [-267.59093921]
#            ----- False branch :)
#               Is 2>=-0.0069240264712428145?
#              ----- True branch :)
#                 Is 4>=0.7075051582809578?
#                ----- True branch :)
#                   Is 1>=1.2219640534876826?
#                  ----- True branch :)
#                     The predicted value --> [-19.83852127]
#                  ----- False branch :)
#                     Is 0>=-0.6294030291794087?
#                    ----- True branch :)
#                       The predicted value --> [-70.84706098]
#                    ----- False branch :)
#                       The predicted value --> [-73.08356158]
#                ----- False branch :)
#                   Is 6>=-0.7044699981613035?
#                  ----- True branch :)
#                     Is 0>=-1.1721619487730692?
#                    ----- True branch :)
#                       Is 1>=0.8252821221834831?
#                      ----- True branch :)
#                         The predicted value --> [-160.61768135]
#                      ----- False branch :)
#                         Is 0>=-0.8414665020506069?
#                        ----- True branch :)
#                           The predicted value --> [-155.92165627]
#                        ----- False branch :)
#                           The predicted value --> [-157.38099053]
#                    ----- False branch :)
#                       The predicted value --> [-138.65859525]
#                  ----- False branch :)
#                     Is 1>=-0.18137434002242014?
#                    ----- True branch :)
#                       Is 0>=-1.0139876302740618?
#                      ----- True branch :)
#                         The predicted value --> [-230.80746163]
#                      ----- False branch :)
#                         The predicted value --> [-231.7876054]
#                    ----- False branch :)
#                       The predicted value --> [-190.82295563]
#              ----- False branch :)
#                 Is 4>=1.4593607437331995?
#                ----- True branch :)
#                   The predicted value --> [-146.43683734]
#                ----- False branch :)
#                   Is 4>=-1.601833450012655?
#                  ----- True branch :)
#                     Is 3>=-0.4026370713314236?
#                    ----- True branch :)
#                       Is 1>=1.4115679594481425?
#                      ----- True branch :)
#                         Is 1>=2.06532210888297?
#                        ----- True branch :)
#                           Is 0>=-0.7838977979066896?
#                          ----- True branch :)
#                             The predicted value --> [-232.98766458]
#                          ----- False branch :)
#                             The predicted value --> [-228.13496894]
#                        ----- False branch :)
#                           The predicted value --> [-213.6245952]
#                      ----- False branch :)
#                         Is 0>=-0.6080690312293994?
#                        ----- True branch :)
#                           The predicted value --> [-227.74269371]
#                        ----- False branch :)
#                           Is 2>=-0.4121681922160472?
#                          ----- True branch :)
#                             The predicted value --> [-169.97662637]
#                          ----- False branch :)
#                             Is 2>=-0.7777349165410316?
#                            ----- True branch :)
#                               The predicted value --> [-208.88597627]
#                            ----- False branch :)
#                               Is 0>=-0.7340297127968468?
#                              ----- True branch :)
#                                 The predicted value --> [-187.99328308]
#                              ----- False branch :)
#                                 Is 0>=-0.7639265578150913?
#                                ----- True branch :)
#                                   The predicted value --> [-193.00725885]
#                                ----- False branch :)
#                                   The predicted value --> [-196.56251772]
#                    ----- False branch :)
#                       Is 4>=0.35550371441154355?
#                      ----- True branch :)
#                         Is 3>=-1.0340318966981963?
#                        ----- True branch :)
#                           Is 0>=-0.8386609544379866?
#                          ----- True branch :)
#                             The predicted value --> [-234.06207911]
#                          ----- False branch :)
#                             The predicted value --> [-222.48842436]
#                        ----- False branch :)
#                           Is 0>=-0.600653295054535?
#                          ----- True branch :)
#                             The predicted value --> [-207.87891497]
#                          ----- False branch :)
#                             The predicted value --> [-216.66144383]
#                      ----- False branch :)
#                         Is 0>=-0.7255274953363342?
#                        ----- True branch :)
#                           The predicted value --> [-239.06458414]
#                        ----- False branch :)
#                           The predicted value --> [-248.51306899]
#                  ----- False branch :)
#                     Is 0>=-0.7493955982357009?
#                    ----- True branch :)
#                       The predicted value --> [-265.89659021]
#                    ----- False branch :)
#                       The predicted value --> [-252.66666428]
#          ----- False branch :)
#             Is 4>=0.7427555558934066?
#            ----- True branch :)
#               Is 3>=0.5134126805380129?
#              ----- True branch :)
#                 Is 1>=0.6285699239147997?
#                ----- True branch :)
#                   The predicted value --> [-139.87031741]
#                ----- False branch :)
#                   Is 0>=-0.3488242853463614?
#                  ----- True branch :)
#                     The predicted value --> [-106.99576804]
#                  ----- False branch :)
#                     The predicted value --> [-91.64822258]
#              ----- False branch :)
#                 Is 0>=-0.47735767156173065?
#                ----- True branch :)
#                   Is 0>=-0.35579805301202666?
#                  ----- True branch :)
#                     The predicted value --> [-213.22650297]
#                  ----- False branch :)
#                     The predicted value --> [-258.90698034]
#                ----- False branch :)
#                   Is 0>=-1.0750799526839634?
#                  ----- True branch :)
#                     Is 0>=-0.7901568373756801?
#                    ----- True branch :)
#                       The predicted value --> [-169.22749574]
#                    ----- False branch :)
#                       The predicted value --> [-143.63256557]
#                  ----- False branch :)
#                     Is 0>=-1.1287134795878464?
#                    ----- True branch :)
#                       The predicted value --> [-191.27227846]
#                    ----- False branch :)
#                       The predicted value --> [-194.79331913]
#            ----- False branch :)
#               Is 6>=-0.7129307059219713?
#              ----- True branch :)
#                 Is 3>=0.6071583174479325?
#                ----- True branch :)
#                   Is 0>=-0.31864072862376813?
#                  ----- True branch :)
#                     The predicted value --> [-119.94281719]
#                  ----- False branch :)
#                     The predicted value --> [-172.33360517]
#                ----- False branch :)
#                   Is 0>=-0.9664885192767696?
#                  ----- True branch :)
#                     Is 0>=-0.24974385969900548?
#                    ----- True branch :)
#                       The predicted value --> [-189.45595598]
#                    ----- False branch :)
#                       Is 0>=-0.49408025928779037?
#                      ----- True branch :)
#                         The predicted value --> [-206.90358911]
#                      ----- False branch :)
#                         Is 0>=-0.7095021530855911?
#                        ----- True branch :)
#                           The predicted value --> [-221.73015433]
#                        ----- False branch :)
#                           The predicted value --> [-216.17190946]
#                  ----- False branch :)
#                     The predicted value --> [-254.94559154]
#              ----- False branch :)
#                 Is 3>=-0.3489256426535791?
#                ----- True branch :)
#                   Is 1>=-1.4718142589630991?
#                  ----- True branch :)
#                     Is 0>=-0.21958942004458265?
#                    ----- True branch :)
#                       The predicted value --> [-281.91191133]
#                    ----- False branch :)
#                       Is 1>=-0.5239415217444655?
#                      ----- True branch :)
#                         Is 0>=-0.2767634553432539?
#                        ----- True branch :)
#                           The predicted value --> [-234.0866418]
#                        ----- False branch :)
#                           Is 0>=-0.5989496177016705?
#                          ----- True branch :)
#                             The predicted value --> [-228.24692303]
#                          ----- False branch :)
#                             The predicted value --> [-230.41514498]
#                      ----- False branch :)
#                         The predicted value --> [-247.12795427]
#                  ----- False branch :)
#                     The predicted value --> [-290.71888774]
#                ----- False branch :)
#                   Is 4>=-0.03921651142094025?
#                  ----- True branch :)
#                     Is 0>=-0.9504387974205132?
#                    ----- True branch :)
#                       The predicted value --> [-269.48159881]
#                    ----- False branch :)
#                       The predicted value --> [-294.23436945]
#                  ----- False branch :)
#                     Is 2>=-0.25881061327295457?
#                    ----- True branch :)
#                       Is 0>=-0.48864128658365713?
#                      ----- True branch :)
#                         The predicted value --> [-317.73650207]
#                      ----- False branch :)
#                         The predicted value --> [-337.05105296]
#                    ----- False branch :)
#                       The predicted value --> [-360.10598752]
#      ----- False branch :)
#         Is 3>=0.8460550381524808?
#        ----- True branch :)
#           Is 5>=-0.03710392928958833?
#          ----- True branch :)
#             Is 2>=0.46848437633758977?
#            ----- True branch :)
#               Is 0>=-1.4219712111564078?
#              ----- True branch :)
#                 The predicted value --> [-161.40205625]
#              ----- False branch :)
#                 The predicted value --> [-159.45460625]
#            ----- False branch :)
#               Is 0>=-1.4243658860365775?
#              ----- True branch :)
#                 The predicted value --> [-165.08185067]
#              ----- False branch :)
#                 The predicted value --> [-168.37383109]
#          ----- False branch :)
#             Is 0>=-1.7208601285746212?
#            ----- True branch :)
#               Is 0>=-1.4956360858390416?
#              ----- True branch :)
#                 Is 0>=-1.4427746470633664?
#                ----- True branch :)
#                   The predicted value --> [-231.18970658]
#                ----- False branch :)
#                   The predicted value --> [-220.90274657]
#              ----- False branch :)
#                 The predicted value --> [-207.72642155]
#            ----- False branch :)
#               The predicted value --> [-180.28715932]
#        ----- False branch :)
#           Is 3>=-1.730766389510077?
#          ----- True branch :)
#             Is 2>=-1.5030769193689015?
#            ----- True branch :)
#               Is 4>=0.008365428120052889?
#              ----- True branch :)
#                 Is 5>=0.24172476792774883?
#                ----- True branch :)
#                   Is 0>=-1.6110958773283688?
#                  ----- True branch :)
#                     Is 0>=-1.4955996722149054?
#                    ----- True branch :)
#                       The predicted value --> [-198.5490585]
#                    ----- False branch :)
#                       The predicted value --> [-212.14964535]
#                  ----- False branch :)
#                     The predicted value --> [-244.60200817]
#                ----- False branch :)
#                   Is 7>=1.1608394765877017?
#                  ----- True branch :)
#                     The predicted value --> [-227.01425632]
#                  ----- False branch :)
#                     Is 0>=-1.5564783576892356?
#                    ----- True branch :)
#                       Is 0>=-1.4103562981915077?
#                      ----- True branch :)
#                         The predicted value --> [-251.4589445]
#                      ----- False branch :)
#                         The predicted value --> [-257.30591747]
#                    ----- False branch :)
#                       Is 3>=-0.126840103117228?
#                      ----- True branch :)
#                         Is 0>=-1.863808361712603?
#                        ----- True branch :)
#                           The predicted value --> [-290.51728169]
#                        ----- False branch :)
#                           The predicted value --> [-291.65154846]
#                      ----- False branch :)
#                         Is 0>=-1.8793067384369762?
#                        ----- True branch :)
#                           The predicted value --> [-268.06375632]
#                        ----- False branch :)
#                           The predicted value --> [-275.11368028]
#              ----- False branch :)
#                 Is 7>=-1.2525872076461633?
#                ----- True branch :)
#                   Is 4>=-1.1699981352687192?
#                  ----- True branch :)
#                     Is 2>=0.8958499746097969?
#                    ----- True branch :)
#                       Is 0>=-1.4946501942480122?
#                      ----- True branch :)
#                         The predicted value --> [-299.2450192]
#                      ----- False branch :)
#                         The predicted value --> [-286.93502173]
#                    ----- False branch :)
#                       Is 1>=0.631402795748175?
#                      ----- True branch :)
#                         The predicted value --> [-304.76673956]
#                      ----- False branch :)
#                         Is 0>=-1.9469184749032262?
#                        ----- True branch :)
#                           Is 0>=-1.3740199477885384?
#                          ----- True branch :)
#                             The predicted value --> [-323.17552148]
#                          ----- False branch :)
#                             The predicted value --> [-319.69695474]
#                        ----- False branch :)
#                           The predicted value --> [-333.14610379]
#                  ----- False branch :)
#                     The predicted value --> [-356.08514882]
#                ----- False branch :)
#                   Is 0>=-1.5862327217076275?
#                  ----- True branch :)
#                     The predicted value --> [-274.27992108]
#                  ----- False branch :)
#                     The predicted value --> [-254.47515585]
#            ----- False branch :)
#               Is 0>=-1.419315023225863?
#              ----- True branch :)
#                 The predicted value --> [-391.9637998]
#              ----- False branch :)
#                 The predicted value --> [-406.01711147]
#          ----- False branch :)
#             The predicted value --> [-485.47665928]
# The r2_score of the trained model 1.0

# %% [markdown]
# # Decision tree Regression using scikit learn for comparision.

# %%
from sklearn.tree import DecisionTreeRegressor as DecisionTreeRegressor_sklearn

# %%
# data is already defined, going to use the same data for comparision.
print("="*100)
print("Number of training data samples-----> {}".format(X.shape[0]))
print("Number of training features --------> {}".format(X.shape[1]))
# Out:
# ====================================================================================================
# Number of training data samples-----> 1000
# Number of training features --------> 8

# %%
decision_tree_reg_sklearn = DecisionTreeRegressor_sklearn()
decision_tree_reg_sklearn.fit(X, y)

# predict the value
y_pred_sklearn = decision_tree_reg_sklearn.predict(X)
socre = r2_score(y, y_pred_sklearn)
print("="*100)
print("r2_score of the prediction is {}".format(socre))
# Out:
# ====================================================================================================
# r2_score of the prediction is 1.0

# %% [markdown]
# # Supervised Machine Learning models scratch series....
# you can also check....
#
# - 1) Linear Regression         ---> https://www.kaggle.com/ninjaac/linear-regression-from-scratch
# - 2) Lasso Regression          ---> https://www.kaggle.com/ninjaac/lasso-and-ridge-regression-from-scratch
# - 3) Ridge Regression          ---> https://www.kaggle.com/ninjaac/lasso-and-ridge-regression-from-scratch
# - 4) ElasticNet Regression     ---> https://www.kaggle.com/ninjaac/elasticnet-regression-from-scratch
# - 5) Polynomail Regression     ---> https://www.kaggle.com/ninjaac/polynomial-and-polynomialridge-regression-scratch
# - 5) PolynomailRidge Regression---> https://www.kaggle.com/ninjaac/polynomial-and-polynomialridge-regression-scratch
# - 6) KNN Classifier            ---> https://www.kaggle.com/ninjaac/knnclassifier-from-scratch
# - 7) Decision Tree Classifier  ---> (Same Notebook you are looking now)
